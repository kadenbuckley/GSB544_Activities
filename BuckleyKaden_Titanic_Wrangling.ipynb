# %% [markdown]
# # Titanic Wrangling
#
# In this practice activity you'll continue to work with the titanic dataset in ways that flex what you've learned about both data wrangling and data visualization.

# %%
import numpy as np
import pandas as pd
from plotnine import *
# Import the titanic dataset here
data_dir = "https://dlsun.github.io/pods/data/"
df_titanic = pd.read_csv(data_dir + "titanic.csv")
#load titanic data
df_titanic
# Out:
#                                 name  gender   age             class embarked  \
# 0                Abbing, Mr. Anthony    male  42.0               3rd        S
# 1          Abbott, Mr. Eugene Joseph    male  13.0               3rd        S
# 2        Abbott, Mr. Rossmore Edward    male  16.0               3rd        S
# 3     Abbott, Mrs. Rhoda Mary 'Rosa'  female  39.0               3rd        S
# 4        Abelseth, Miss. Karen Marie  female  16.0               3rd        S
# ...                              ...     ...   ...               ...      ...
# 2202                Wynn, Mr. Walter    male  41.0         deck crew        B
# 2203             Yearsley, Mr. Harry    male  40.0  victualling crew        S
# 2204        Young, Mr. Francis James    male  32.0  engineering crew        S
# 2205             Zanetti, Sig. Minio    male  20.0  restaurant staff        S
# 2206              Zarracchi, Sig. L.    male  26.0  restaurant staff        S
#
# ...

# %% [markdown]
# ## 1. Filter the data to include passengers only. Calculate the joint distribution (cross-tab) between a passenger's class and where they embarked.

# %%
# Code here
#Filter data to include passengers only
df_po = df_titanic[(df_titanic["class"] == "1st") | (df_titanic["class"] == "2nd") | (df_titanic["class"] == "3rd")]

#Create Cross-tab for class and embarked
pd.crosstab(df_po["class"], df_po["embarked"])
# Out:
# embarked  B    C    Q    S
# class
# 1st       3  143    3  175
# 2nd       6   26    7  245
# 3rd       0  102  113  494

# %% [markdown]
# ## 2. Using the joint distribution that calculated above, calculate the following:
#
# * the conditional distribution of their class given where they embarked
# * the conditional distribution of where they embarked given their class
#
# Use the conditional distributions that you calculate to answer the following quesitons:
#
# * What proportion of 3rd class passengers embarked at Southampton?
# * What proportion of Southampton passengers were in 3rd class?

# %%
# Code here
#Calculate cond. dist. of class given where they embarked
cge = pd.crosstab(df_po["class"], df_po["embarked"], normalize=True)
print(cge)

#Calculate cond. dist. of where they embarked given class
egc = pd.crosstab(df_po["embarked"], df_po["class"], normalize=True)
print(egc)
# Out:
# embarked         B         C         Q         S
# class
# 1st       0.002278  0.108580  0.002278  0.132878
# 2nd       0.004556  0.019742  0.005315  0.186029
# 3rd       0.000000  0.077449  0.085801  0.375095
# class          1st       2nd       3rd
# embarked
# B         0.002278  0.004556  0.000000
# C         0.108580  0.019742  0.077449
# Q         0.002278  0.005315  0.085801
# S         0.132878  0.186029  0.375095

# %%
#proportion of 3rd class passengers embarked at Southampton
class3_sh = 0.375095 / (0 + 0.077449 + 0.085801 + 0.375095)
class3_sh
# Out:
# 0.6967557978619657

# %%
#proportion of Southampton passengers in 3rd class
sh_class3 = 0.375095 / (0.132878 + 0.186029 + 0.375095)
sh_class3
# Out:
# 0.5404811513511488

# %% [markdown]
# ## 3. Make a visualization showing the distribution of a passenger's class, given where they embarked.
#
# Discuss the pros and cons of using this visualization versus the distributions you calculated before, to answer the previous questions.

# %%
# Code here
#Passenger column
df_titanic["passenger_class"] = df_titanic["class"].map({
    "1st": "passenger",
    "2nd": "passenger",
    "3rd": "passenger",
    "victualling crew": "crew",
    "engineering crew": "crew",
    "deck crew": "crew"
})

df_passenger = df_titanic[df_titanic["passenger_class"]=="passenger"]


plot1 = (ggplot(df_passenger, aes("embarked",fill = "class"))
+ geom_bar(position='fill')
+ labs(title='Passenger Class | Embark Location', x='Embark Location', y='Proportion'))
plot1
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Providing a visualization in this case gives a much better sense of the whole picture. Calculating only numbers, as we did before, makes things much harder to interpret. With a plot such as this one, we can now compare proportions of passengers based on their class, given all of the embark locations. A con to a visualiation such as this one is a loss of exact information, whereas the calculations provided previously show exact proprtions.
